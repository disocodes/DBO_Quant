# %% [markdown]
# # DBO_Quant — Databricks + OpenBB Quant Platform
# This launcher runs the repository-native Databricks source notebook. Keep this file in the same Databricks Git folder as `Databricks_OpenBB_Quant_Platform_Final.py`.

# %%
# %run ./Databricks_OpenBB_Quant_Platform_Final
